# %%
# %load_ext autoreload
# %autoreload 2

# %%
# am i inside a docker container ?
import os
print(os.environ.get("DOCKER", "not started with docker :("))
# Out:
# true

# %%
import pandas as pd
# Out:
# /tmp/ipykernel_111/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("tv-news-2022-french.csv",header=1, sep='\t', quotechar='"')

# %%
df.describe()
# Out:
#                   0            12          12.1
# count  22704.000000  22704.000000  22704.000000
# mean       4.053999      6.780479     15.751145
# std        4.169375      3.334247      8.789908
# min        0.000000      1.000000      1.000000
# 25%        0.000000      4.000000      8.000000
# 50%        3.000000      7.000000     16.000000
# 75%        7.000000     10.000000     23.000000
# max       41.000000     12.000000     31.000000

# %%
df.head()
# Out:
#   \12 euros par semaine pour manger\" : avec l'inflation, les banques d'aide alimentaire sont débordées"  \
# 0  \Adieu Paris\" : Baer, Poelvorde, Damiens, Ard...
# 1  \Allo la France\" : la pénurie de carburant me...
# 2  \Argent gâché\", \"écosystème menacé\"... Une ...
# 3  \Avec grands regrets, il y a 500 km !\" : le p...
# 4  \Bloody Sunday\" : 50 ans après, un traumatism...
#
# ...
